# %% [markdown]
# ### Load the libraries

# %%
from Bio import SeqIO
import re
# import math

# %%
# Primary libraries
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Secondary libraries
from tqdm import tqdm
# from scipy import stats
import scipy
# from glob import glob
import os
# from matplotlib import dates as mpl_dates
# import datetime
# from datetime import date
import matplotlib.patches as mpatches
# from matplotlib import cm
# from colorspacious import cspace_converter
# from collections import OrderedDict
# import matplotlib.ticker as ticker
from scipy.interpolate import make_interp_spline, BSpline

# %% [markdown]
# ### Visualization-I

# %% [markdown]
# #### Baci

# %%
df_gaag_baci_up = pd.read_csv('./csv_files_for_motifs/GAAG_upstream_bacillus_subtilis.csv', 
                              header=0, names=['relative_pos', 'frequency'])
df_gaaa_baci_up = pd.read_csv('./csv_files_for_motifs/GAAA_upstream_bacillus_subtilis.csv', 
                              header=0, names=['relative_pos', 'frequency'])

# %%
df_gaag_baci_up
# Out:
#      relative_pos  frequency
# 0            -200         33
# 1            -199         37
# 2            -198         39
# 3            -197         32
# 4            -196         20
# ..            ...        ...
# 195            -5         18
# 196            -4         29
# 197            -3         15
# 198            -2          0
# 199            -1          0
#
# [200 rows x 2 columns]

# %%
# # plt.style.use('default')
# plt.style.use('fivethirtyeight')

# plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
# plt.grid(True)

# plt.title('Bacillus Subtilis')
# plt.xlabel('Relative position from start site (+1)')
# plt.ylabel('Frequency of motifs starting at a position')
# # plt.title('Bacillus Subtilis', fontsize = 28, pad=25)
# # plt.ylabel(f'Percentage mutation\n(n = {nseqs:,} sequences)', fontsize = 24)
# # plt.xlabel('Relative position from start site (+1)', fontsize = 24, labelpad=20)

# plt.plot(df_gaag_baci_up.relative_pos, df_gaag_baci_up.frequency, label="5'-GAAG-3'",
#          marker='o', markersize=1)
# plt.plot(df_gaaa_baci_up.relative_pos, df_gaaa_baci_up.frequency, label="5'-GAAA-3'", 
#          marker='o', markersize=1)
# # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
# # plt.yticks(fontsize=20)

# max_val = 200
# # Adding patches for regions (according to NCBI annotation)
# # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
# consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
#                               color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
# plt.gca().add_patch(consensus_region_1)

# consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
#                               color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
# plt.gca().add_patch(consensus_region_2)

# plt.ylim(0, 200)
# plt.xlim(-201, +2)
# # plt.xticks(rotation=90)
# # plt.xticks(fontsize="x-large")
# # plt.yticks(fontsize="x-large")
# plt.legend(loc = 'best')
# # plt.legend(fontsize="x-large")
# # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')

# %% [markdown]
# ##### Smoothening using BSpline

# %% [markdown]
# Source: https://stackoverflow.com/questions/5283649/plot-smooth-line-with-pyplot

# %%
# # 900 is the number of points added on X-axis to smoothen the curve using BSpline approach

# xnew_GAAG = np.linspace(df_gaag_baci_up.relative_pos.min(), df_gaag_baci_up.relative_pos.max(), 900) 

# spl = make_interp_spline(df_gaag_baci_up.relative_pos, df_gaag_baci_up.frequency, k=3)  # type: BSpline
# GAAG_baci_up_frequency_smooth = spl(xnew_GAAG)


# xnew_GAAA = np.linspace(df_gaaa_baci_up.relative_pos.min(), df_gaaa_baci_up.relative_pos.max(), 900) 

# spl = make_interp_spline(df_gaaa_baci_up.relative_pos, df_gaaa_baci_up.frequency, k=3)  # type: BSpline
# GAAA_baci_up_frequency_smooth = spl(xnew_GAAA)

# %%
# # plt.style.use('default')
# plt.style.use('fivethirtyeight')

# plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
# plt.grid(True)

# plt.title('Bacillus Subtilis')
# plt.xlabel('Relative position from start site (+1)')
# plt.ylabel('Frequency of motifs starting at a position')

# plt.plot(xnew_GAAG, GAAG_baci_up_frequency_smooth, label="5'-GAAG-3'",
#          marker='o', markersize=1)
# plt.plot(xnew_GAAA, GAAA_baci_up_frequency_smooth, label="5'-GAAA-3'",
#          marker='o', markersize=1)
# max_val = 200
# # Adding patches for regions (according to NCBI annotation)
# # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
# consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
#                               color="#CCBFE9", alpha=0.7, linewidth=1, label='[-12, -7]')
# plt.gca().add_patch(consensus_region_1)

# consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
#                               color="#B8E9E4", alpha=0.7, linewidth=1, label='[-35, -30]')
# plt.gca().add_patch(consensus_region_2)

# plt.ylim(0, 200)
# plt.xlim(-201, +2)
# # plt.xticks(rotation=90)
# # plt.xticks(fontsize="x-large")
# # plt.yticks(fontsize="x-large")
# plt.legend(loc = 'best')

# plt.show()

# %% [markdown]
# #### Strep

# %%
df_gaag_strep_up = pd.read_csv('./csv_files_for_motifs/GAAG_upstream_streptococcus_pneumoniae.csv', 
                              header=0, names=['relative_pos', 'frequency'])
df_gaaa_strep_up = pd.read_csv('./csv_files_for_motifs/GAAA_upstream_streptococcus_pneumoniae.csv', 
                              header=0, names=['relative_pos', 'frequency'])

# %%
df_gaag_strep_up
# Out:
#      relative_pos  frequency
# 0            -200         12
# 1            -199         17
# 2            -198         16
# 3            -197         15
# 4            -196         10
# ..            ...        ...
# 195            -5         20
# 196            -4         19
# 197            -3          5
# 198            -2          0
# 199            -1          0
#
# [200 rows x 2 columns]

# %%
# # plt.style.use('default')
# plt.style.use('fivethirtyeight')

# plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
# plt.grid(True)

# plt.title('Streptococcus Pneumoniae')
# plt.xlabel('Relative position from start site (+1)')
# plt.ylabel('Frequency of motifs starting at a position')
# # plt.title('Streptococcus Pneumoniae', fontsize = 28, pad=25)
# # plt.ylabel(f'Percentage mutation\n(n = {nseqs:,} sequences)', fontsize = 24)
# # plt.xlabel('Relative position from start site (+1)', fontsize = 24, labelpad=20)

# plt.plot(df_gaag_strep_up.relative_pos, df_gaag_strep_up.frequency, label="5'-GAAG-3'", 
#          marker='o', markersize=0.5)
# plt.plot(df_gaaa_strep_up.relative_pos, df_gaaa_strep_up.frequency,label="5'-GAAA-3'", 
#          marker='o', markersize=0.5)
# # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
# # plt.yticks(fontsize=20)

# max_val = 130
# # Adding patches for regions (according to NCBI annotation)
# # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
# consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
#                               color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
# plt.gca().add_patch(consensus_region_1)

# consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
#                               color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
# plt.gca().add_patch(consensus_region_2)

# plt.ylim(0, 130)
# plt.xlim(-201, +2)
# # plt.xticks(rotation=90)
# # plt.xticks(fontsize="x-large")
# # plt.yticks(fontsize="x-large")
# plt.legend(loc = 'best')
# # plt.legend(fontsize="x-large")
# # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')

# %% [markdown]
# #### Kleb

# %%
df_gaag_kleb_up = pd.read_csv('./csv_files_for_motifs/GAAG_upstream_klebsiella_pneumoniae.csv', 
                              header=0, names=['relative_pos', 'frequency'])
df_gaaa_kleb_up = pd.read_csv('./csv_files_for_motifs/GAAA_upstream_klebsiella_pneumoniae.csv', 
                              header=0, names=['relative_pos', 'frequency'])

# %%
df_gaag_kleb_up
# Out:
#      relative_pos  frequency
# 0            -200         29
# 1            -199         20
# 2            -198         34
# 3            -197         30
# 4            -196         32
# ..            ...        ...
# 195            -5         37
# 196            -4         19
# 197            -3          5
# 198            -2          8
# 199            -1          0
#
# [200 rows x 2 columns]

# %%
# # plt.style.use('default')
# plt.style.use('fivethirtyeight')

# plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
# plt.grid(True)

# plt.title('Klebsiella Pneumoniae')
# plt.xlabel('Relative position from start site (+1)')
# plt.ylabel('Frequency of motifs starting at a position')
# # plt.title('Mutations (All)', fontsize = 28, pad=25)
# # plt.ylabel(f'Percentage mutation\n(n = {nseqs:,} sequences)', fontsize = 24)
# # plt.xlabel('Relative position from start site (+1)', fontsize = 24, labelpad=20)

# plt.plot(df_gaag_kleb_up.relative_pos, df_gaag_kleb_up.frequency, label="5'-GAAG-3'", 
#          marker='o', markersize=0.5)
# plt.plot(df_gaaa_kleb_up.relative_pos, df_gaaa_kleb_up.frequency,label="5'-GAAA-3'", 
#          marker='o', markersize=0.5)
# # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
# # plt.yticks(fontsize=20)

# max_val = 130
# # Adding patches for regions (according to NCBI annotation)
# # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
# consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
#                               color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
# plt.gca().add_patch(consensus_region_1)

# consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
#                               color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
# plt.gca().add_patch(consensus_region_2)

# plt.ylim(0, 130)
# plt.xlim(-201, +2)
# # plt.xticks(rotation=90)
# # plt.xticks(fontsize="x-large")
# # plt.yticks(fontsize="x-large")
# plt.legend(loc = 'best')
# # plt.legend(fontsize="x-large")
# # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')

# %% [markdown]
# ### Visualization-II: Using Sliding window analysis

# %%
# # To do the flank calculations for all files
# directory = os.fsencode('./csv_files_for_motifs/')

# for file in os.listdir(directory):
#     filename = os.fsdecode(file)
#     if filename.endswith('.csv'):
#         print(filename)
#         genbank_file_reader(filename)

# %%
list_of_dfs = [df_gaag_baci_up, df_gaaa_baci_up, 
               df_gaag_strep_up, df_gaaa_strep_up, 
               df_gaag_kleb_up, df_gaaa_kleb_up]

for df in list_of_dfs:
    df['MA_mean'] = df['frequency'
                 ].rolling(window=10, closed='both'
                          ).mean()
    df['MA_sum'] = df['frequency'
                 ].rolling(window=10, closed='both'
                          ).sum()

# %%
df_gaag_baci_up.name = 'Bacillus Subtilis' 
df_gaaa_baci_up.name = 'Bacillus Subtilis'
df_gaag_strep_up.name = 'Streptococcus Pneumoniae'
df_gaaa_strep_up.name = 'Streptococcus Pneumoniae'
df_gaag_kleb_up.name = 'Klebsiella Pneumoniae'
df_gaaa_kleb_up.name = 'Klebsiella Pneumoniae'

# %% [markdown]
# ##### Frequency plots

# %%
# Frequency plots

list_of_list_of_dfs = [[df_gaag_baci_up, df_gaaa_baci_up], 
               [df_gaag_strep_up, df_gaaa_strep_up], 
               [df_gaag_kleb_up, df_gaaa_kleb_up]]

for dfs_list in list_of_list_of_dfs:
    
    # print(f'df[0].name = {dfs_list[0].name}, df[1].name = {dfs_list[1]}')
#     print(dfs_list)
    plt.style.use('fivethirtyeight')
    plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
    plt.grid(True)

    plt.title(dfs_list[0].name)
    plt.xlabel('Relative position from start site (+1)')
    plt.ylabel('Frequency of motifs starting at a position')

    plt.plot(dfs_list[0].relative_pos, dfs_list[0].frequency, label="5'-GAAG-3'", 
             marker='o', markersize=0.5)
    plt.plot(dfs_list[1].relative_pos, dfs_list[1].frequency,label="5'-GAAA-3'", 
             marker='o', markersize=0.5)
    # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
    # plt.yticks(fontsize=20)
#     print(max(max(dfs_list[0]), max(dfs_list[1])))
    max_val = max(max(dfs_list[0].frequency), max(dfs_list[1].frequency)) + 20
    # Adding patches for regions (according to NCBI annotation)
    # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
    consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
                                  color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
    plt.gca().add_patch(consensus_region_1)

    consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
                                  color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
    plt.gca().add_patch(consensus_region_2)

    plt.ylim(0, max_val)
    plt.xlim(-201, +2)
    # plt.xticks(rotation=90)
    # plt.xticks(fontsize="x-large")
    # plt.yticks(fontsize="x-large")
    plt.legend(loc = 'best')
    # plt.legend(fontsize="x-large")
    # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')

# %% [markdown]
# ##### Mean SWAN plots

# %%
# # MA_Mean- SWAN plots


# list_of_list_of_dfs = [[df_gaag_baci_up, df_gaaa_baci_up], 
#                [df_gaag_strep_up, df_gaaa_strep_up], 
#                [df_gaag_kleb_up, df_gaaa_kleb_up]]

# for dfs_list in list_of_list_of_dfs:
    
#     # print(f'df[0].name = {dfs_list[0].name}, df[1].name = {dfs_list[1]}')
# #     print(dfs_list)
#     plt.style.use('fivethirtyeight')
#     plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
#     plt.grid(True)

#     plt.title(dfs_list[0].name)
#     plt.xlabel('Relative position from start site (+1)')
#     plt.ylabel('Mean Frequency of motifs\nstarting at a position in a\nwindow of size 10')

#     plt.plot(dfs_list[0].relative_pos, dfs_list[0].MA_mean, label="5'-GAAG-3'", 
#              marker='o', markersize=0.5)
#     plt.plot(dfs_list[1].relative_pos, dfs_list[1].MA_mean,label="5'-GAAA-3'", 
#              marker='o', markersize=0.5)
#     # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
#     # plt.yticks(fontsize=20)
#     max_val = max(dfs_list[0].MA_mean.max(), dfs_list[1].MA_mean.max()) + 20
#     print(max_val)
#     # Adding patches for regions (according to NCBI annotation)
#     # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
#     consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
#                                   color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
#     plt.gca().add_patch(consensus_region_1)

#     consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
#                                   color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
#     plt.gca().add_patch(consensus_region_2)

#     plt.ylim(0, max_val)
#     plt.xlim(-201, +2)
#     # plt.xticks(rotation=90)
#     # plt.xticks(fontsize="x-large")
#     # plt.yticks(fontsize="x-large")
#     plt.legend(loc = 'best')
#     # plt.legend(fontsize="x-large")
#     # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')
# Out:
# 118.72727272727273
# 89.45454545454545
# 80.0

# %% [markdown]
# ##### Cumulative SWAN plots

# %%
# # MA_sum- SWAN plots


# list_of_list_of_dfs = [[df_gaag_baci_up, df_gaaa_baci_up], 
#                [df_gaag_strep_up, df_gaaa_strep_up], 
#                [df_gaag_kleb_up, df_gaaa_kleb_up]]

# for dfs_list in list_of_list_of_dfs:
    
#     # print(f'df[0].name = {dfs_list[0].name}, df[1].name = {dfs_list[1]}')
# #     print(dfs_list)
#     plt.style.use('fivethirtyeight')
#     plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
#     plt.grid(True)

#     plt.title(dfs_list[0].name)
#     plt.xlabel('Relative position from start site (+1)')
#     plt.ylabel('Cumulative Frequency of motifs\nstarting at a position in a\nwindow of size 10')

#     plt.plot(dfs_list[0].relative_pos, dfs_list[0].MA_sum, label="5'-GAAG-3'", 
#              marker='o', markersize=0.5)
#     plt.plot(dfs_list[1].relative_pos, dfs_list[1].MA_sum,label="5'-GAAA-3'", 
#              marker='o', markersize=0.5)
#     # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
#     # plt.yticks(fontsize=20)
#     max_val = max(dfs_list[0].MA_sum.max(), dfs_list[1].MA_sum.max()) + 20
#     print(max_val)
#     # Adding patches for regions (according to NCBI annotation)
#     # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
#     consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
#                                   color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
#     plt.gca().add_patch(consensus_region_1)

#     consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
#                                   color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
#     plt.gca().add_patch(consensus_region_2)

#     plt.ylim(0, max_val)
#     plt.xlim(-201, +2)
#     # plt.xticks(rotation=90)
#     # plt.xticks(fontsize="x-large")
#     # plt.yticks(fontsize="x-large")
#     plt.legend(loc = 'best')
#     # plt.legend(fontsize="x-large")
#     # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')
# Out:
# 1106.0
# 784.0
# 680.0

# %% [markdown]
# ##### Mean normalization: MA_sum SWAN plots

# %%
# # Norm 1: Mean normalization: MA_sum- SWAN plots


# list_of_list_of_dfs = [[df_gaag_baci_up, df_gaaa_baci_up], 
#                [df_gaag_strep_up, df_gaaa_strep_up], 
#                [df_gaag_kleb_up, df_gaaa_kleb_up]]

# for dfs_list in list_of_list_of_dfs:
    
#     # print(f'df[0].name = {dfs_list[0].name}, df[1].name = {dfs_list[1]}')
# #     print(dfs_list)
#     normalized_series_of_df0=(dfs_list[0].MA_sum-dfs_list[0].MA_sum.mean())/dfs_list[0].MA_sum.std()
#     normalized_series_of_df1=(dfs_list[1].MA_sum-dfs_list[1].MA_sum.mean())/dfs_list[1].MA_sum.std()
    
#     plt.style.use('fivethirtyeight')
#     plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
#     plt.grid(True)

#     plt.title(dfs_list[0].name)
#     plt.xlabel('Relative position from start site (+1)')
#     plt.ylabel('Normalized cumulative Frequency\n of motifs starting at a position\nin a window of size 10')

#     plt.plot(dfs_list[0].relative_pos, normalized_series_of_df0, label="5'-GAAG-3'", 
#              marker='o', markersize=0.5)
#     plt.plot(dfs_list[1].relative_pos, normalized_series_of_df1,label="5'-GAAA-3'", 
#              marker='o', markersize=0.5)
#     # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
#     # plt.yticks(fontsize=20)
#     min_val = -1.5
#     max_val = max(normalized_series_of_df0.max(), normalized_series_of_df1.max()
#                  ) + max(normalized_series_of_df0.std(), normalized_series_of_df1.std())
#     print(max_val)
#     # Adding patches for regions (according to NCBI annotation)
#     # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
#     consensus_region_1 = mpatches.Rectangle((-12, min_val-1), 5, max_val+10, fill=True,
#                                   color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
#     plt.gca().add_patch(consensus_region_1)

#     consensus_region_2 = mpatches.Rectangle((-35, min_val-1), 5, max_val+10, fill=True,
#                                   color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
#     plt.gca().add_patch(consensus_region_2)

#     plt.ylim(min_val, max_val)
#     plt.xlim(-201, +2)
#     # plt.xticks(rotation=90)
#     # plt.xticks(fontsize="x-large")
#     # plt.yticks(fontsize="x-large")
#     plt.legend(loc = 'best')
#     # plt.legend(fontsize="x-large")
#     # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')
# Out:
# 5.445232906478207
# 5.630895203500539
# 5.840825305729262

# %% [markdown]
# ##### Min-Max normalization: MA_sum SWAN plots

# %%
# # Norm 2: Min-Max normalization: MA_sum- SWAN plots


# list_of_list_of_dfs = [[df_gaag_baci_up, df_gaaa_baci_up], 
#                [df_gaag_strep_up, df_gaaa_strep_up], 
#                [df_gaag_kleb_up, df_gaaa_kleb_up]]

# for dfs_list in list_of_list_of_dfs:
    
#     # print(f'df[0].name = {dfs_list[0].name}, df[1].name = {dfs_list[1]}')
# #     print(dfs_list)
#     normalized_series_of_df0=(dfs_list[0].MA_sum-dfs_list[0].MA_sum.min())/(dfs_list[0].MA_sum.max()-dfs_list[0].MA_sum.min())
#     normalized_series_of_df1=(dfs_list[1].MA_sum-dfs_list[1].MA_sum.min())/(dfs_list[1].MA_sum.max()-dfs_list[1].MA_sum.min())
    
#     plt.style.use('fivethirtyeight')
#     plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
#     plt.grid(True)

#     plt.title(dfs_list[0].name)
#     plt.xlabel('Relative position from start site (+1)')
#     plt.ylabel('Normalized cumulative Frequency\n of motifs starting at a position\nin a window of size 10')

#     plt.plot(dfs_list[0].relative_pos, normalized_series_of_df0, label="5'-GAAG-3'", 
#              marker='o', markersize=0.5)
#     plt.plot(dfs_list[1].relative_pos, normalized_series_of_df1,label="5'-GAAA-3'", 
#              marker='o', markersize=0.5)
#     # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
#     # plt.yticks(fontsize=20)
#     min_val = -0.02
#     max_val = max(normalized_series_of_df0.max(), normalized_series_of_df1.max()
#                  ) + max(normalized_series_of_df0.std(), normalized_series_of_df1.std())
#     print(max_val)
#     # Adding patches for regions (according to NCBI annotation)
#     # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
#     consensus_region_1 = mpatches.Rectangle((-12, min_val-1), 5, max_val+10, fill=True,
#                                   color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
#     plt.gca().add_patch(consensus_region_1)

#     consensus_region_2 = mpatches.Rectangle((-35, min_val-1), 5, max_val+10, fill=True,
#                                   color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
#     plt.gca().add_patch(consensus_region_2)

#     plt.ylim(min_val, max_val)
#     plt.xlim(-201, +2)
#     # plt.xticks(rotation=90)
#     # plt.xticks(fontsize="x-large")
#     # plt.yticks(fontsize="x-large")
#     plt.legend(loc = 'best')
#     # plt.legend(fontsize="x-large")
#     # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')
# Out:
# 1.191051519948444
# 1.205159627803441
# 1.170281034118989

# %% [markdown]
# ##### Division by summed value normalization: MA_sum- SWAN plots

# %%
# Norm 2: Division by summed value normalization: MA_sum- SWAN plots


list_of_list_of_dfs = [[df_gaag_baci_up, df_gaaa_baci_up], 
               [df_gaag_strep_up, df_gaaa_strep_up], 
               [df_gaag_kleb_up, df_gaaa_kleb_up]]

for dfs_list in list_of_list_of_dfs:
    
    # print(f'df[0].name = {dfs_list[0].name}, df[1].name = {dfs_list[1]}')
#     print(dfs_list)
    normalized_series_of_df0 = dfs_list[0].MA_sum / dfs_list[0].MA_sum.sum()
    normalized_series_of_df1 = dfs_list[1].MA_sum / dfs_list[1].MA_sum.sum()
    
    plt.style.use('fivethirtyeight')
    plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
    plt.grid(True)

    plt.title(dfs_list[0].name)
    plt.xlabel('Relative position from start site (+1)')
    plt.ylabel('Normalized cumulative Frequency\n of motifs starting at a position\nin a window of size 10')

    plt.plot(dfs_list[0].relative_pos, normalized_series_of_df0, label="5'-GAAG-3'", 
             marker='o', markersize=0.5)
    plt.plot(dfs_list[1].relative_pos, normalized_series_of_df1,label="5'-GAAA-3'", 
             marker='o', markersize=0.5)
    # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
    # plt.yticks(fontsize=20)
    min_val = 0
    max_val = max(normalized_series_of_df0.max(), normalized_series_of_df1.max()
                 ) + max(normalized_series_of_df0.std(), normalized_series_of_df1.std())
    print(max_val)
    # Adding patches for regions (according to NCBI annotation)
    # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
    consensus_region_1 = mpatches.Rectangle((-12, min_val-1), 5, max_val+10, fill=True,
                                  color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
    plt.gca().add_patch(consensus_region_1)

    consensus_region_2 = mpatches.Rectangle((-35, min_val-1), 5, max_val+10, fill=True,
                                  color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
    plt.gca().add_patch(consensus_region_2)

    plt.ylim(min_val, max_val)
    plt.xlim(-201, +2)
    # plt.xticks(rotation=90)
    # plt.xticks(fontsize="x-large")
    # plt.yticks(fontsize="x-large")
    plt.legend(loc = 'best')
    # plt.legend(fontsize="x-large")
    # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')
# Out:
# 0.01181469892815344
# 0.014793319340088882
# 0.010950560138908447

# %% [markdown]
# ##### Rough

# %%
# df.loc[df.index[np.arange(len(df))%by==1],'New']

# %%
# list_of_dfs = [df_gaag_baci_up, df_gaaa_baci_up, 
#                df_gaag_strep_up, df_gaaa_strep_up, 
#                df_gaag_kleb_up, df_gaaa_kleb_up]

# for df in list_of_dfs:
#     df['MA_mean'] = df['frequency'
#                  ].rolling(window=10, closed='both'
#                           ).mean()
#     df['MA_sum'] = df['frequency'
#                  ].rolling(window=10, closed='both'
#                           ).sum()

# %%
# by = 10

# df_gaaa_baci_up.loc[df_gaaa_baci_up.index[(np.arange(len(
#     df_gaaa_baci_up))+1) % by == 1], 'MA_sum_slide_by_10'] = df_gaaa_baci_up.frequency.rolling(window=10, closed='both'
#                                                                                         ).mean()
# df_gaaa_baci_up

# # df_gaaa_baci_up[df_gaaa_baci_up.index[np.arange(
# #     len(df_gaaa_baci_up)) % by == 1], 'MA_sum_slide_10'] = df_gaaa_baci_up.MA_sum

# # df_gaaa_baci_up['MA_sum_slide_by_10'].iloc[lambda x: x.index % 10 == 0] = df_gaaa_baci_up.iloc[lambda x: x.index % 10 == 0
# #                                                                         ]['frequency'
# #                                                                    ].rolling(window=10, closed='both'
# #                                                                             ).mean()
# Out:
#      relative_pos  frequency    MA_mean  MA_sum  MA_sum_slide_by_10
# 0            -200         53        NaN     NaN                 NaN
# 1            -199         44        NaN     NaN                 NaN
# 2            -198         67        NaN     NaN                 NaN
# 3            -197         51        NaN     NaN                 NaN
# 4            -196         62        NaN     NaN                 NaN
# ..            ...        ...        ...     ...                 ...
# 195            -5         63  68.909091   758.0                 NaN
# 196            -4         55  63.909091   703.0                 NaN
# 197            -3        110  69.818182   768.0                 NaN
# 198            -2          1  68.363636   752.0                 NaN
# 199            -1          0  66.727273   734.0                 NaN
#
# [200 rows x 5 columns]

# %%
# by = 10

# df_gaag_baci_up.loc[df_gaag_baci_up.index[(np.arange(len(
#     df_gaag_baci_up))+1) % by == 1], 'MA_sum_slide_by_10'] = df_gaag_baci_up.frequency.rolling(window=10, closed='both'
#                                                                                         ).mean()
# df_gaag_baci_up

# # df_gaag_baci_up[df_gaag_baci_up.index[np.arange(
# #     len(df_gaag_baci_up)) % by == 1], 'MA_sum_slide_10'] = df_gaag_baci_up.MA_sum

# # df_gaag_baci_up['MA_sum_slide_by_10'].iloc[lambda x: x.index % 10 == 0] = df_gaag_baci_up.iloc[lambda x: x.index % 10 == 0
# #                                                                         ]['frequency'
# #                                                                    ].rolling(window=10, closed='both'
# #                                                                             ).mean()
# Out:
#      relative_pos  frequency    MA_mean  MA_sum  MA_sum_slide_by_10
# 0            -200         33        NaN     NaN                 NaN
# 1            -199         37        NaN     NaN                 NaN
# 2            -198         39        NaN     NaN                 NaN
# 3            -197         32        NaN     NaN                 NaN
# 4            -196         20        NaN     NaN                 NaN
# ..            ...        ...        ...     ...                 ...
# 195            -5         18  52.181818   574.0                 NaN
# 196            -4         29  47.454545   522.0                 NaN
# 197            -3         15  41.090909   452.0                 NaN
# 198            -2          0  36.272727   399.0                 NaN
# 199            -1          0  31.909091   351.0                 NaN
#
# [200 rows x 5 columns]

# %%
# del df_gaaa_baci_up['MA_sum_slide_by_10']

# %%
# df_gaaa_baci_up
# Out:
#      relative_pos  frequency    MA_mean  MA_sum  MA_sum_slide_by_10
# 0            -200         53        NaN     NaN                 NaN
# 1            -199         44        NaN     NaN                 NaN
# 2            -198         67        NaN     NaN                 NaN
# 3            -197         51        NaN     NaN                 NaN
# 4            -196         62        NaN     NaN                 NaN
# ..            ...        ...        ...     ...                 ...
# 195            -5         63  68.909091   758.0                 NaN
# 196            -4         55  63.909091   703.0                 NaN
# 197            -3        110  69.818182   768.0                 NaN
# 198            -2          1  68.363636   752.0                 NaN
# 199            -1          0  66.727273   734.0                 NaN
#
# [200 rows x 5 columns]

# %%
# df_gaaa_baci_up[~df_gaaa_baci_up.MA_sum_slide_by_10.isnull()]
# Out:
#      relative_pos  frequency    MA_mean  MA_sum  MA_sum_slide_by_10
# 10           -190         43  52.000000   572.0           52.000000
# 20           -180         34  46.545455   512.0           46.545455
# 30           -170         44  52.181818   574.0           52.181818
# 40           -160         52  48.636364   535.0           48.636364
# 50           -150         50  45.727273   503.0           45.727273
# 60           -140         44  51.181818   563.0           51.181818
# 70           -130         49  46.818182   515.0           46.818182
# 80           -120         48  52.454545   577.0           52.454545
# 90           -110         60  52.272727   575.0           52.272727
# 100          -100         42  52.181818   574.0           52.181818
# 110           -90         48  53.090909   584.0           53.090909
# 120           -80         78  54.818182   603.0           54.818182
# 130           -70         56  55.090909   606.0           55.090909
# 140           -60         52  51.636364   568.0           51.636364
# 150           -50         52  50.545455   556.0           50.545455
# 160           -40         53  49.272727   542.0           49.272727
# 170           -30         56  54.636364   601.0           54.636364
# 180           -20         83  64.000000   704.0           64.000000
# 190           -10         46  85.000000   935.0           85.000000

# %%
# # plt.style.use('default')
# plt.style.use('fivethirtyeight')

# plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
# plt.grid(True)

# plt.title('Bacillus Subtilis')
# plt.xlabel('Relative position from start site (+1)')
# plt.ylabel('Frequency of motifs starting at a position')
# # plt.title('Bacillus Subtilis', fontsize = 28, pad=25)
# # plt.ylabel(f'Percentage mutation\n(n = {nseqs:,} sequences)', fontsize = 24)
# # plt.xlabel('Relative position from start site (+1)', fontsize = 24, labelpad=20)

# plt.plot(df_gaag_baci_up.relative_pos, df_gaag_baci_up.MA_sum_slide_by_10, label="5'-GAAG-3'",
#          marker='o', markersize=3)
# plt.plot(df_gaaa_baci_up.relative_pos, df_gaaa_baci_up.MA_sum_slide_by_10, label="5'-GAAA-3'", 
#          marker='o', markersize=3)
# # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
# # plt.yticks(fontsize=20)

# max_val = 100
# # Adding patches for regions (according to NCBI annotation)
# # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
# consensus_region_1 = mpatches.Rectangle((-12, 0), 5, max_val, fill=True,
#                               color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
# plt.gca().add_patch(consensus_region_1)

# consensus_region_2 = mpatches.Rectangle((-35, 0), 5, max_val, fill=True,
#                               color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
# plt.gca().add_patch(consensus_region_2)

# plt.ylim(0, 100)
# plt.xlim(-201, +2)
# # plt.xticks(rotation=90)
# # plt.xticks(fontsize="x-large")
# # plt.yticks(fontsize="x-large")
# plt.legend(loc = 'best')
# # plt.legend(fontsize="x-large")
# # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')

# %%
# # Norm 2: Division by summed value normalization: MA_sum- SWAN plots


# list_of_list_of_dfs = [[df_gaag_baci_up, df_gaaa_baci_up], 
#                [df_gaag_strep_up, df_gaaa_strep_up], 
#                [df_gaag_kleb_up, df_gaaa_kleb_up]]

# for dfs_list in list_of_list_of_dfs:
    
#     # print(f'df[0].name = {dfs_list[0].name}, df[1].name = {dfs_list[1]}')
# #     print(dfs_list)
#     normalized_series_of_df0 = dfs_list[0].frequency / dfs_list[0].frequency.sum()
#     normalized_series_of_df1 = dfs_list[1].frequency / dfs_list[1].frequency.sum()
    
#     plt.style.use('fivethirtyeight')
#     plt.figure(figsize=(15, 5), facecolor=(1, 1, 1))
#     plt.grid(True)

#     plt.title(dfs_list[0].name)
#     plt.xlabel('Relative position from start site (+1)')
#     plt.ylabel('Normalized Frequency of motifs starting at a position')

#     plt.plot(dfs_list[0].relative_pos, normalized_series_of_df0, label="5'-GAAG-3'", 
#              marker='o', markersize=0.5, linewidth=1.5)
#     plt.plot(dfs_list[1].relative_pos, normalized_series_of_df1,label="5'-GAAA-3'", 
#              marker='o', markersize=0.5, linewidth=1.5)
#     # plt.xticks(np.arange(min(df_heatmap_per_pt1.genome_positions), max(df_heatmap_per_pt1.genome_positions)+1, 500), rotation=90, fontsize=20)
#     # plt.yticks(fontsize=20)
#     min_val = 0
#     max_val = max(normalized_series_of_df0.max(), normalized_series_of_df1.max()
#                  ) + max(normalized_series_of_df0.std(), normalized_series_of_df1.std())
#     print(max_val)
#     # Adding patches for regions (according to NCBI annotation)
#     # Consensus regions (colors- peach: #F6C9BC, purple: #CCBFE9, skyblue: #B8E9E4)
#     consensus_region_1 = mpatches.Rectangle((-12, min_val-1), 5, max_val+10, fill=True,
#                                   color="#CCBFE9", alpha=0.7, linewidth=1, label='Consensus region: [-12, -7]')
#     plt.gca().add_patch(consensus_region_1)

#     consensus_region_2 = mpatches.Rectangle((-35, min_val-1), 5, max_val+10, fill=True,
#                                   color="#B8E9E4", alpha=0.7, linewidth=1, label='Consensus region: [-35, -30]')
#     plt.gca().add_patch(consensus_region_2)

#     plt.ylim(min_val, max_val)
#     plt.xlim(-201, +2)
#     # plt.xticks(rotation=90)
#     # plt.xticks(fontsize="x-large")
#     # plt.yticks(fontsize="x-large")
#     plt.legend(loc = 'best')
#     # plt.legend(fontsize="x-large")
#     # plt.savefig('plots_void_story/ma7_top5000.png', dpi=1000, bbox_inches='tight')
# Out:
# 0.018500056770592996
# 0.02024672703551876
# 0.019039892343060274
